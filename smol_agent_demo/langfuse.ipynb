# %%
import os
from dotenv import load_dotenv
load_dotenv(".env.log")

# Get keys for your project from the project settings page: https://cloud.langfuse.com
public_key = os.environ.get("LANGFUSE_PUBLIC_KEY")
secret_key = os.environ.get("LANGFUSE_SECRET_KEY")
host = os.environ.get("LANGFUSE_BASE_URL")

print(f"Connected to host: {host}")
# Out:
# Connected to host: https://cloud.langfuse.com

# %%
from langfuse import get_client
 
langfuse = get_client()
 
# Verify connection
if langfuse.auth_check():
    print("Langfuse client is authenticated and ready!")
else:
    print("Authentication failed. Please check your credentials and host.")
# Out:
# Langfuse client is authenticated and ready!

# %%
from openinference.instrumentation.smolagents import SmolagentsInstrumentor

SmolagentsInstrumentor().instrument()

# %%
from smolagents import CodeAgent, InferenceClientModel

agent = CodeAgent(tools=[], model=InferenceClientModel())
alfred_agent = agent.from_hub('sergiopaniego/AlfredAgent', trust_remote_code=True)
alfred_agent.run("Give me the best playlist for a party at Wayne's mansion. The party idea is a 'villain masquerade' theme")
# Out:
# Fetching 14 files:   0%|          | 0/14 [00:00<?, ?it/s]
# C:\Users\Jakaria.Ahmed\AppData\Roaming\Python\Python312\site-packages\huggingface_hub\file_download.py:143: UserWarning: `huggingface_hub` cache-system uses symlinks by default to efficiently store duplicated files but your machine does not support them in C:\Users\Jakaria.Ahmed\.cache\huggingface\hub\spaces--sergiopaniego--AlfredAgent. Caching files will still work but in a degraded version that might require more space on your disk. This warning can be disabled by setting the `HF_HUB_DISABLE_SYMLINKS_WARNING` environment variable. For more details, see https://huggingface.co/docs/huggingface_hub/how-to-cache#limitations.
# To support symlinks on Windows, you either need to activate Developer Mode or to run Python as an administrator. In order to activate developer mode, see this article: https://docs.microsoft.com/en-us/windows/apps/get-started/enable-your-device-for-development
#   warnings.warn(message)
# README.md:   0%|          | 0.00/257 [00:00<?, ?B/s]
# .gitattributes: 0.00B [00:00, ?B/s]
# agent.json: 0.00B [00:00, ?B/s]
# requirements.txt:   0%|          | 0.00/50.0 [00:00<?, ?B/s]
# app.py: 0.00B [00:00, ?B/s]
# prompts.yaml: 0.00B [00:00, ?B/s]
# catering_service_tool.py:   0%|          | 0.00/945 [00:00<?, ?B/s]
# superhero_party_theme_generator.py: 0.00B [00:00, ?B/s]
# final_answer.py:   0%|          | 0.00/448 [00:00<?, ?B/s]
# suggest_menu.py:   0%|          | 0.00/822 [00:00<?, ?B/s]
# visit_webpage.py: 0.00B [00:00, ?B/s]
# web_search.py: 0.00B [00:00, ?B/s]
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[13], line 4
#       1 from smolagents import CodeAgent, InferenceClientModel
#       3 agent = CodeAgent(tools=[], model=InferenceClientModel())
# ----> 4 alfred_agent = agent.from_hub('sergiopaniego/AlfredAgent', trust_remote_code=True)
#       5 alfred_agent.run("Give me the best playlist for a party at Wayne's mansion. The party idea is a 'villain masquerade' theme")
#
# File ~\AppData\Roaming\Python\Python312\site-packages\smolagents\agents.py:1102, in MultiStepAgent.from_hub(cls, repo_id, token, trust_remote_code, **kwargs)
#    1089 download_kwargs = {"token": token, "repo_type": "space"} | {
#    1090     key: kwargs.pop(key)
#    1091     for key in [
#    (...)
#    1098     if key in kwargs
#    1099 }
#    1101 download_folder = Path(snapshot_download(repo_id=repo_id, **download_kwargs))
# -> 1102 return cls.from_folder(download_folder, **kwargs)
#
# File ~\AppData\Roaming\Python\Python312\site-packages\smolagents\agents.py:1134, in MultiStepAgent.from_folder(cls, folder, **kwargs)
#    1131 if managed_agents:
#    1132     kwargs["managed_agents"] = managed_agents
# -> 1134 return cls.from_dict(agent_dict, **kwargs)
#
# File ~\AppData\Roaming\Python\Python312\site-packages\smolagents\agents.py:1780, in CodeAgent.from_dict(cls, agent_dict, **kwargs)
#    1778 code_agent_kwargs.update(kwargs)
#    1779 # Call the parent class's from_dict method
# -> 1780 return super().from_dict(agent_dict, **code_agent_kwargs)
#
# File ~\AppData\Roaming\Python\Python312\site-packages\smolagents\agents.py:1019, in MultiStepAgent.from_dict(cls, agent_dict, **kwargs)
#    1017 # Load model
#    1018 model_info = agent_dict["model"]
# -> 1019 model_class = getattr(importlib.import_module("smolagents.models"), model_info["class"])
#    1020 model = model_class.from_dict(model_info["data"])
#    1021 # Load tools
#
# AttributeError: module 'smolagents.models' has no attribute 'HfApiModel'
