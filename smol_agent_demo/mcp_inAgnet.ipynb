# %%
! pip install "smolagents[mcp]"

# %%
import os
from smolagents import ToolCollection, CodeAgent
from mcp import StdioServerParameters
from smolagents import InferenceClientModel


model = InferenceClientModel("Qwen/Qwen2.5-Coder-32B-Instruct")


server_parameters = StdioServerParameters(
    command="uvx",
    args=["--quiet", "pubmedmcp@0.1.3"],
    env={"UV_PYTHON": "3.12", **os.environ},
)

with ToolCollection.from_mcp(server_parameters, trust_remote_code=True) as tool_collection:
    agent = CodeAgent(tools=[*tool_collection.tools], model=model, add_base_tools=True)
    agent.run("Please find a remedy for hangover.")
# Out:
# c:\Program Files\Python312\Lib\contextlib.py:137: FutureWarning: Parameter 'structured_output' was not specified. Currently it defaults to False, but in version 1.25, the default will change to True. To suppress this warning, explicitly set structured_output=True (new behavior) or structured_output=False (legacy behavior). See documentation at https://huggingface.co/docs/smolagents/tutorials/tools#structured-output-and-output-schema-support for more details.
#   return next(self.gen)
# Exception in thread Thread-5 (_run_loop):
# Traceback (most recent call last):
#   File "C:\Users\Jakaria.Ahmed\AppData\Roaming\Python\Python312\site-packages\mcp\os\win32\utilities.py", line 169, in create_windows_process
#     process = await anyio.open_process(
#               ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\Jakaria.Ahmed\AppData\Roaming\Python\Python312\site-packages\anyio\_core\_subprocesses.py", line 190, in open_process
#     return await get_async_backend().open_process(
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\Jakaria.Ahmed\AppData\Roaming\Python\Python312\site-packages\anyio\_backends\_asyncio.py", line 2561, in open_process
#     process = await asyncio.create_subprocess_exec(
#               ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Program Files\Python312\Lib\asyncio\subprocess.py", line 224, in create_subprocess_exec
#     transport, protocol = await loop.subprocess_exec(
#                           ^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Program Files\Python312\Lib\asyncio\base_events.py", line 1743, in subprocess_exec
#     transport = await self._make_subprocess_transport(
#                 ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Program Files\Python312\Lib\asyncio\base_events.py", line 524, in _make_subprocess_transport
#     raise NotImplementedError
# NotImplementedError
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\Jakaria.Ahmed\AppData\Roaming\Python\Python312\site-packages\mcp\os\win32\utilities.py", line 209, in _create_windows_fallback_process
#     popen_obj = subprocess.Popen(
#                 ^^^^^^^^^^^^^^^^^
#   File "c:\Program Files\Python312\Lib\subprocess.py", line 992, in __init__
#     errread, errwrite) = self._get_handles(stdin, stdout, stderr)
#                          ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Program Files\Python312\Lib\subprocess.py", line 1406, in _get_handles
#     errwrite = msvcrt.get_osfhandle(stderr.fileno())
#                                     ^^^^^^^^^^^^^^^
#   File "C:\Users\Jakaria.Ahmed\AppData\Roaming\Python\Python312\site-packages\ipykernel\iostream.py", line 371, in fileno
#     raise io.UnsupportedOperation(msg)
# io.UnsupportedOperation: fileno
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "c:\Program Files\Python312\Lib\threading.py", line 1075, in _bootstrap_inner
#     self.run()
#   File "C:\Users\Jakaria.Ahmed\AppData\Roaming\Python\Python312\site-packages\ipykernel\ipkernel.py", line 766, in run_closure
#     _threading_Thread_run(self)
#   File "c:\Program Files\Python312\Lib\threading.py", line 1012, in run
#     self._target(*self._args, **self._kwargs)
#   File "C:\Users\Jakaria.Ahmed\AppData\Roaming\Python\Python312\site-packages\mcpadapt\core.py", line 244, in _run_loop
#     self.loop.run_until_complete(self.task)
#   File "c:\Program Files\Python312\Lib\asyncio\base_events.py", line 687, in run_until_complete
#     return future.result()
#            ^^^^^^^^^^^^^^^
#   File "C:\Users\Jakaria.Ahmed\AppData\Roaming\Python\Python312\site-packages\mcpadapt\core.py", line 233, in setup
#     await stack.enter_async_context(
#   File "c:\Program Files\Python312\Lib\contextlib.py", line 659, in enter_async_context
#     result = await _enter(cm)
#              ^^^^^^^^^^^^^^^^
#   File "c:\Program Files\Python312\Lib\contextlib.py", line 210, in __aenter__
#     return await anext(self.gen)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\Jakaria.Ahmed\AppData\Roaming\Python\Python312\site-packages\mcpadapt\core.py", line 129, in mcptools
#     async with client as (read, write, *_):
#                ^^^^^^
#   File "c:\Program Files\Python312\Lib\contextlib.py", line 210, in __aenter__
#     return await anext(self.gen)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\Jakaria.Ahmed\AppData\Roaming\Python\Python312\site-packages\mcp\client\stdio\__init__.py", line 124, in stdio_client
#     process = await _create_platform_compatible_process(
#               ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\Jakaria.Ahmed\AppData\Roaming\Python\Python312\site-packages\mcp\client\stdio\__init__.py", line 249, in _create_platform_compatible_process
#     process = await create_windows_process(command, args, env, errlog, cwd)
#               ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\Jakaria.Ahmed\AppData\Roaming\Python\Python312\site-packages\mcp\os\win32\utilities.py", line 181, in create_windows_process
#     process = await _create_windows_fallback_process(command, args, env, errlog, cwd)
#               ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\Jakaria.Ahmed\AppData\Roaming\Python\Python312\site-packages\mcp\os\win32\utilities.py", line 221, in _create_windows_fallback_process
#     popen_obj = subprocess.Popen(
#                 ^^^^^^^^^^^^^^^^^
#   File "c:\Program Files\Python312\Lib\subprocess.py", line 992, in __init__
#     errread, errwrite) = self._get_handles(stdin, stdout, stderr)
#                          ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Program Files\Python312\Lib\subprocess.py", line 1406, in _get_handles
#     errwrite = msvcrt.get_osfhandle(stderr.fileno())
#                                     ^^^^^^^^^^^^^^^
#   File "C:\Users\Jakaria.Ahmed\AppData\Roaming\Python\Python312\site-packages\ipykernel\iostream.py", line 371, in fileno
#     raise io.UnsupportedOperation(msg)
# io.UnsupportedOperation: fileno
# ---------------------------------------------------------------------------
# TimeoutError                              Traceback (most recent call last)
# Cell In[1], line 16
#       7 model = InferenceClientModel("Qwen/Qwen2.5-Coder-32B-Instruct")
#      10 server_parameters = StdioServerParameters(
#      11     command="uvx",
#      12     args=["--quiet", "pubmedmcp@0.1.3"],
#      13     env={"UV_PYTHON": "3.12", **os.environ},
#      14 )
# ---> 16 with ToolCollection.from_mcp(server_parameters, trust_remote_code=True) as tool_collection:
#      17     agent = CodeAgent(tools=[*tool_collection.tools], model=model, add_base_tools=True)
#      18     agent.run("Please find a remedy for hangover.")
#
# File c:\Program Files\Python312\Lib\contextlib.py:137, in _GeneratorContextManager.__enter__(self)
#     135 del self.args, self.kwds, self.func
#     136 try:
# --> 137     return next(self.gen)
#     138 except StopIteration:
#     139     raise RuntimeError("generator didn't yield") from None
#
# File ~\AppData\Roaming\Python\Python312\site-packages\smolagents\tools.py:1057, in ToolCollection.from_mcp(cls, server_parameters, trust_remote_code, structured_output)
#    1052 if not trust_remote_code:
#    1053     raise ValueError(
#    1054         "Loading tools from MCP requires you to acknowledge you trust the MCP server, "
#    1055         "as it will execute code on your local machine: pass `trust_remote_code=True`."
#    1056     )
# -> 1057 with MCPAdapt(server_parameters, SmolAgentsAdapter(structured_output=structured_output)) as tools:
#    1058     yield cls(tools)
#
# File ~\AppData\Roaming\Python\Python312\site-packages\mcpadapt\core.py:310, in MCPAdapt.__enter__(self)
#     309 def __enter__(self):
# --> 310     self.start()
#     311     return self.tools()
#
# File ~\AppData\Roaming\Python\Python312\site-packages\mcpadapt\core.py:298, in MCPAdapt.start(self)
#     296 # check connection to mcp server is ready
#     297 if not self.ready.wait(timeout=self.connect_timeout):
# --> 298     raise TimeoutError(
#     299         f"Couldn't connect to the MCP server after {self.connect_timeout} seconds"
#     300     )
#
# TimeoutError: Couldn't connect to the MCP server after 30 seconds
