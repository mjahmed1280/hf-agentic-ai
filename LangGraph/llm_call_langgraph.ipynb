# %%
import os
from langchain_google_genai import ChatGoogleGenerativeAI

# Set API key
# os.environ["GEMINI_API_KEY"] = os.getenv("GEMINI_API_KEYS")
api_key = os.getenv("GEMINI_API_KEYS")

# Create LLM class
llm = ChatGoogleGenerativeAI(
    model= "gemini-3-flash-preview",
    temperature=1.0,
    max_retries=2,
    google_api_key=api_key,
)

# Bind tools to the model
# model = llm.bind_tools([get_weather_forecast])

# Test the model with tools
res=llm.invoke(f"What is climate type of India")

print(res)
# Out:
# content="India’s climate is broadly described as a **Tropical Monsoon climate**.\n\nHowever, because of its vast size and varied geography (ranging from the Himalayan mountains to the coastal plains), India is home to a wide range of climatic zones. According to the **Köppen climate classification system**, India can be divided into several distinct types:\n\n### 1. Tropical Wet (Humid)\n*   **Tropical Monsoon Climate:** Found along the Western Ghats, the Malabar Coast, and parts of Northeast India (like Assam and Tripura). These areas experience high temperatures and heavy seasonal rainfall.\n*   **Tropical Wet and Dry (Savanna) Climate:** This is the most common climate type in India, covering most of the inland peninsular plateau. It has a distinct dry season in winter and early summer.\n\n### 2. Arid and Semi-Arid\n*   **Tropical Semi-Arid (Steppe) Climate:** Found in a long strip east of the Western Ghats (rain shadow area) and parts of Gujarat and southern Punjab/Haryana.\n*   **Subtropical Arid (Desert) Climate:** This covers the Thar Desert in Rajasthan. It is characterized by very high temperatures and extremely low rainfall.\n\n### 3. Subtropical Humid\n*   **Humid Subtropical Climate:** This covers most of Northern and Northeastern India (the Indo-Gangetic plains). It features hot summers and relatively cool winters, with most rainfall occurring during the monsoon.\n\n### 4. Mountain/Alpine\n*   **Montane/Himalayan Climate:** Found in the high-altitude regions of the Himalayas. The temperature falls as altitude increases, ranging from subtropical at the base to tundra-like conditions (permanent snow and ice) at the highest peaks.\n\n---\n\n### The Four Main Seasons\nThe India Meteorological Department (IMD) officially recognizes four seasons:\n1.  **Winter (December to February):** Dry and cool, though the south remains warm.\n2.  **Summer (March to May):** Extremely hot, especially in the central and northern plains.\n3.  **Monsoon (June to September):** The rainy season, driven by the southwest monsoon winds. This is the most important season for India’s agriculture.\n4.  **Post-Monsoon/Retreating Monsoon (October to November):** A transition period where the monsoon winds withdraw, often bringing rain to the southeastern coast (Tamil Nadu).\n\n### Key Factors Influencing India's Climate\n*   **The Himalayas:** They act as a barrier, blocking cold winds from Central Asia and trapping the monsoon winds within the subcontinent.\n*   **The Thar Desert:** Its high heat in summer creates a low-pressure zone that pulls in moisture-laden winds from the Indian Ocean (the Monsoon).\n*   **Surrounding Oceans:** The Arabian Sea and the Bay of Bengal moderate the temperatures of the coastal regions." additional_kwargs={} response_metadata={'prompt_feedback': {'block_reason': 0, 'safety_ratings': []}, 'finish_reason': 'STOP', 'safety_ratings': []} id='run--a7097ccf-4aa1-4fde-9f25-d0f85eaa555d-0' usage_metadata={'input_tokens': 7, 'output_tokens': 600, 'total_tokens': 1070}
